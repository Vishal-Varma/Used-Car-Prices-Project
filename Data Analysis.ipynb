# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
COLOR_SCHEME = px.colors.sequential.Teal_r

# %% [markdown]
# ### <code>Data Reading</code> and <code>Preprocessing</code>

# %%
data = pd.read_csv("./Data/used_car_prices_dataset.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15411 non-null  int64
#  1   car_name           15411 non-null  object
#  2   brand              15411 non-null  object
#  3   model              15411 non-null  object
#  4   vehicle_age        15411 non-null  int64
#  5   km_driven          15411 non-null  int64
#  6   seller_type        15411 non-null  object
#  7   fuel_type          15411 non-null  object
#  8   transmission_type  15411 non-null  object
#  9   mileage            15411 non-null  float64
#  10  engine             15411 non-null  int64
#  11  max_power          15411 non-null  float64
#  12  seats              15411 non-null  int64
#  13  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 1.6+ MB

# %%
print(f"Duplicate Records : {data.duplicated().sum()}")
# Out:
# Duplicate Records : 0

# %% [markdown]
# - Data contains around <code>15.4k</code> records and <code>14</code> columns.
# - <code>Null values</code> are absent.
# - There are <code>167</code> duplicate records.

# %% [markdown]
# Dropping <code>duplicate</code> records

# %%
data.drop_duplicates(inplace = True)
print(f"Duplicate Records : {data.duplicated().sum()}")
# Out:
# Duplicate Records : 0

# %% [markdown]
# Dropping unnecessary column <code>Unnamed: 0</code>

# %%
data.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
data.describe().T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_06c65_row0_col0, #T_06c65_row0_col1, #T_06c65_row0_col2, #T_06c65_row0_col3, #T_06c65_row0_col4, #T_06c65_row0_col5, #T_06c65_row0_col6, #T_06c65_row0_col7, #T_06c65_row1_col0, #T_06c65_row1_col3, #T_06c65_row2_col0, #T_06c65_row2_col1, #T_06c65_row2_col2, #T_06c65_row2_col3, #T_06c65_row2_col4, #T_06c65_row2_col5, #T_06c65_row2_col6, #T_06c65_row2_col7, #T_06c65_row3_col0, #T_06c65_row3_col1, #T_06c65_row3_col2, #T_06c65_row3_col4, #T_06c65_row3_col5, #T_06c65_row3_col6, #T_06c65_row3_col7, #T_06c65_row4_col0, #T_06c65_row4_col1, #T_06c65_row4_col2, #T_06c65_row4_col3, #T_06c65_row4_col4, #T_06c65_row4_col5, #T_06c65_row4_col6, #T_06c65_row4_col7, #T_06c65_row5_col0, #T_06c65_row5_col1, #T_06c65_row5_col2, #T_06c65_row5_col3, #T_06c65_row5_col4, #T_06c65_row5_col5, #T_06c65_row5_col6, #T_06c65_row5_col7, #T_06c65_row6_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_06c65_row1_col1 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_06c65_row1_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_06c65_row1_col4 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_06c65_row1_col5 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_06c65_row1_col6 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_06c65_row1_col7 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_06c65_row3_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_06c65_row6_col1, #T_06c65_row6_col2, #T_06c65_row6_col3, #T_06c65_row6_col4, #T_06c65_row6_col5, #T_06c65_row6_col6, #T_06c65_row6_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_06c65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06c65_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_06c65_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_06c65_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_06c65_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_06c65_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_06c65_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_06c65_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_06c65_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06c65_level0_row0" class="row_heading level0 row0" >vehicle_age</th>
#       <td id="T_06c65_row0_col0" class="data row0 col0" >15411.000000</td>
#       <td id="T_06c65_row0_col1" class="data row0 col1" >6.036338</td>
#       <td id="T_06c65_row0_col2" class="data row0 col2" >3.013291</td>
#       <td id="T_06c65_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_06c65_row0_col4" class="data row0 col4" >4.000000</td>
#       <td id="T_06c65_row0_col5" class="data row0 col5" >6.000000</td>
#       <td id="T_06c65_row0_col6" class="data row0 col6" >8.000000</td>
#       <td id="T_06c65_row0_col7" class="data row0 col7" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_
col7" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row6" class="row_heading level0 row6" >selling_price</th>
#       <td id="T_06c65_row6_col0" class="data row6 col0" >15411.000000</td>
#       <td id="T_06c65_row6_col1" class="data row6 col1" >774971.116410</td>
#       <td id="T_06c65_row6_col2" class="data row6 col2" >894128.363263</td>
#       <td id="T_06c65_row6_col3" class="data row6 col3" >40000.000000</td>
#       <td id="T_06c65_row6_col4" class="data row6 col4" >385000.000000</td>
#       <td id="T_06c65_row6_col5" class="data row6 col5" >556000.000000</td>
#       <td id="T_06c65_row6_col6" class="data row6 col6" >825000.000000</td>
#       <td id="T_06c65_row6_col7" class="data row6 col7" >39500000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - <code>vehicle_age</code> : Around 6 years (most between 4–8 years)
# - <code>km_driven</code> : Median around 50,000 km (large outliers present)
# - <code>mileage</code> : Avg around 20 km/l
# - <code>engine</code> : Typical size is around 1,200 – 1,600 cc
# - <code>max_power</code> : Around 75 – 117 bhp
# - <code>seats</code> : Mostly 5 seats
# - <code>selling_price</code> : Median is around Rs 5.6 lakh (most between Rs 3.8–8.2 lakh)

# %% [markdown]
# ### <code>Data Analysis</code>

# %% [markdown]
# Distribution of Selling Price

# %%
fig = go.Figure()
fig.add_trace(
    go.Box(
        x = data["selling_price"],
        marker = dict(
            color = COLOR_SCHEME[0]
        ),
        name = "Selling Price Box Plot"
    )
)
fig.add_trace(
    go.Violin(
        x = data["selling_price"],
        marker = dict(
            color = COLOR_SCHEME[1]
        ),
        name = "Selling Price Violin Plot"
    )
)
fig.update_layout(
    title = "Selling Price Distribution - Box and Violin Plot",
    xaxis = dict(
        title = "Selling Price"
    ),
    yaxis = dict(
        showticklabels = False
    )
)
fig.update_traces(
    hovertemplate = "<b>Selling Price</b> : %{x}<br>"
)
fig.show()

# %%
median_selling_price_by_seller_type = data.groupby("seller_type")["selling_price"].median().reset_index().sort_values(by = "selling_price", ascending = False)

fig = px.bar(
    data_frame = median_selling_price_by_seller_type,
    x = "seller_type",
    y = "selling_price",
    color = "seller_type",
    color_discrete_sequence = COLOR_SCHEME,
    text_auto = True
)
fig.update_layout(
    title = "Median Selling Price by Seller Type",
    xaxis = dict(
        title = "Seller Type"
    ),
    yaxis = dict(
        title = "Median Selling Price",
        range = [500000, 600000]
    ),
    showlegend = False
)
fig.update_traces(
    hovertemplate = "<b>Seller Type</b> : %{x}<br>" + "<b>Median Selling Price</b> : %{y}<br>"
)
fig.show()

# %% [markdown]
# Vehicle Age Distribution

# %%
fig = px.histogram(
    data_frame = data,
    x = "vehicle_age",
    color_discrete_sequence = COLOR_SCHEME
)
fig.update_layout(
    title = "Vehicle Age Distribution",
    xaxis = dict(
        title = "Vehicle Age (in years)"
    ),
    yaxis = dict(
        title = "Frequency"
    )
)
fig.update_traces(
    hovertemplate = "<b>Vehicle Age</b> : %{x}<br>" + "<b>Frequency</b> : %{y}<br>"
)
fig.show()

# %% [markdown]
# Vehicle Age vs KM Driven

# %%
fig = px.scatter(
    data_frame = data,
    x = "km_driven",
    y = "vehicle_age",
    color_discrete_sequence = COLOR_SCHEME
)
fig.update_layout(
    title = "Vehicle Age vs KMs Driven",
    xaxis = dict(
        title = "KMs Driven"
    ),
    yaxis = dict(
        title = "Vehicle Age (in years)"
    )
)
fig.update_traces(
    hovertemplate = "<b>KMs Driven</b> : %{x}<br>" + "<b>Vehicle Age</b> : %{y} years<br>"
)
fig.show()

# %% [markdown]
# Mileage vs Engine Size

# %%
fig = px.scatter(
    data_frame = data,
    x = "mileage",
    y = "engine",
    color_discrete_sequence = COLOR_SCHEME
)
fig.update_layout(
    title = "Mileage vs Engine Size",
    xaxis = dict(
        title = "Mileage"
    ),
    yaxis = dict(
        title = "Engine Size"
    )
)
fig.update_traces(
    hovertemplate = "<b>Mileage</b> : %{x}<br>" + "<b>Engine Size</b> : %{y}<br>"
)
fig.show()

# %% [markdown]
# Engine size vs Max power

# %%
fig = px.scatter(
    data_frame = data,
    x = "max_power",
    y = "engine",
    color_discrete_sequence = COLOR_SCHEME
)
fig.update_layout(
    title = "Max Power vs Engine Size",
    xaxis = dict(
        title = "Max Power"
    ),
    yaxis = dict(
        title = "Engine Size"
    )
)
fig.update_traces(
    hovertemplate = "<b>Max Power</b> : %{x}<br>" + "<b>Engine Size</b> : %{y}<br>"
)
fig.show()

# %% [markdown]
# Vehicle Age vs Mileage

# %%
data["age_groups"] = pd.cut(
    data["vehicle_age"],
    bins = [0, 5, 10, 15, 20],
    labels = ["0 - 5 years", "6 - 10 years", "11 - 15 years", "16 - 20 years"]
)

fig = px.box(
    data_frame = data.sort_values(by = "age_groups"),
    y = "age_groups",
    x = "selling_price",
    color_discrete_sequence = COLOR_SCHEME
)
fig.update_layout(
    title = "Selling Price vs Vehicle Age Groups",
    yaxis = dict(
        title = "Vehicle Age Groups"
    ),
    xaxis = dict(
        title = "Selling Price"
    )
)
fig.update_traces(
    hovertemplate = "<b>Vehicle Age Group</b> : %{y}<br>" + "<b>Selling Price</b> : %{x}<br>"
)
fig.show()

# %% [markdown]
# KM Driven vs Mileage

# %%
fig = px.scatter(
    data_frame = data,
    x = "mileage",
    y = "km_driven",
    color_discrete_sequence = COLOR_SCHEME
)
fig.update_layout(
    title = "Mileage vs KMs Driven",
    xaxis = dict(
        title = "Mileage"
    ),
    yaxis = dict(
        title = "KMs Driven"
    )
)
fig.update_traces(
    hovertemplate = "<b>Mileage</b> : %{x}<br>" + "<b>KMs Driven</b> : %{y} km<br>"
)
fig.show()

# %% [markdown]
# Correlation Matrix

# %%
fig = px.imshow(
    data[data.select_dtypes(include = np.number).columns].corr().round(2),
    color_continuous_scale = COLOR_SCHEME[::-1],
    text_auto = True
)
fig.update_layout(
    title = "Correlation Matrix of Numerical Features"
)
fig.show()

# %% [markdown]
# ### <code>Observations</code>

# %% [markdown]
# - Most vehicles in the dataset are between <code>4</code> and <code>10</code> years old.
# - <code>Newer cars</code> around <code>0 – 5</code> years old command significantly <code>higher</code> prices than older vehicles.
# - <code>Dealer-listed</code> cars have the <code>highest</code> median prices, while <code>individual</code> sellers list cars <code>cheaper</code>.
# - <code>Older</code> vehicles generally have <code>higher</code> kilometers driven.
# - <code>Mileage</code> <code>decreases</code> as <code>engine size</code> <code>increases</code>.
# - <code>Mileage</code> shows little clear trend with <code>distance driven</code>, but extreme <code>outliers</code> exist.
# - <code>Larger</code> <code>engine sizes</code> generally produce <code>higher</code> <code>max power</code>.
# - <code>Selling price</code> is <code>highly</code> correlated with <code>max power</code> and <code>engine size</code>.
