# %% [markdown]
# ##### <strong><code>Aim</code></strong> : To create a model that predicts <i>used car</i> prices based on historical data, with high accuracy.

# %% [markdown]
# ##### <code>Activities Performed</code>

# %% [markdown]
# 1. Importing necessary <code>libraries</code>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# 2. Data reading

# %%
data = pd.read_csv("./Data/used_car_prices_dataset.csv")

# %% [markdown]
# Dropping unnecessary column

# %%
data.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
data.describe().style.background_gradient().format(precision = 2)
# Out:
# <style type="text/css">
# #T_90bdc_row0_col0, #T_90bdc_row0_col2, #T_90bdc_row0_col3, #T_90bdc_row0_col4, #T_90bdc_row0_col5, #T_90bdc_row7_col1, #T_90bdc_row7_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_90bdc_row0_col1, #T_90bdc_row1_col4, #T_90bdc_row6_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_90bdc_row0_col6, #T_90bdc_row1_col0, #T_90bdc_row1_col2, #T_90bdc_row1_col5, #T_90bdc_row2_col0, #T_90bdc_row2_col2, #T_90bdc_row2_col3, #T_90bdc_row2_col4, #T_90bdc_row2_col5, #T_90bdc_row3_col0, #T_90bdc_row3_col1, #T_90bdc_row3_col2, #T_90bdc_row3_col4, #T_90bdc_row3_col5, #T_90bdc_row3_col6, #T_90bdc_row4_col0, #T_90bdc_row4_col2, #T_90bdc_row4_col4, #T_90bdc_row4_col5, #T_90bdc_row5_col0, #T_90bdc_row5_col2, #T_90bdc_row5_col4, #T_90bdc_row5_col5, #T_90bdc_row6_col0, #T_90bdc_row6_col2, #T_90bdc_row6_col5, #T_90bdc_row7_col0, #T_90bdc_row7_col2, #T_90bdc_row7_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_90bdc_row1_col1, #T_90bdc_row1_col6, #T_90bdc_row2_col1, #T_90bdc_row3_col3, #T_90bdc_row5_col1, #T_90bdc_row5_col6, #T_90bdc_row6_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_90bdc_row1_col3 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_90bdc_row2_col6, #T_90bdc_row6_col6 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_90bdc_row4_col1, #T_90bdc_row4_col6 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_90bdc_row4_col3, #T_90bdc_row5_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_90bdc_row6_col3 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_90bdc_row7_col3 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_90bdc_row7_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# </style>
# <table id="T_90bdc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90bdc_level0_col0" class="col_heading level0 col0" >vehicle_age</th>
#       <th id="T_90bdc_level0_col1" class="col_heading level0 col1" >km_driven</th>
#       <th id="T_90bdc_level0_col2" class="col_heading level0 col2" >mileage</th>
#       <th id="T_90bdc_level0_col3" class="col_heading level0 col3" >engine</th>
#       <th id="T_90bdc_level0_col4" class="col_heading level0 col4" >max_power</th>
#       <th id="T_90bdc_level0_col5" class="col_heading level0 col5" >seats</th>
#       <th id="T_90bdc_level0_col6" class="col_heading level0 col6" >selling_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90bdc_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_90bdc_row0_col0" class="data row0 col0" >15411.00</td>
#       <td id="T_90bdc_row0_col1" class="data row0 col1" >15411.00</td>
#       <td id="T_90bdc_row0_col2" class="data row0 col2" >15411.00</td>
#       <td id="T_90bdc_row0_col3" class="data row0 col3" >15411.00</td>
#       <td id="T_90bdc_row0_col4" class="data row0 col4" >15411.00</td>
#       <td id="T_90bdc_row0_col5" class="data row0 col5" >15411.00</td>
#       <td id="T_90bdc_row0_col6" class="data row0 col6" >15411.00</td>
#     </tr>
#     <tr>
#       <th id="T_90bdc_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_90bdc_row1_col0" class="data row1 col0" >6.04</td>
#       <td id="T_90bdc_row1_col1" class="data row1 col1" >55616.48</td>
#       <td id="T_90bdc_row1_col2" class="data row1 col2" >19.70</td>
#       <td id="T_90bdc_row1_col3" class="data row1 col3" >1486.06</td>
#       <td id="T_90bdc_row1_col4" class="data row1 col4" >100.59</td>
#       <td id="T_90bdc_row1_col5" class="data row1 col5" >5.33</td>
#       <td id="T_90bdc_row1_col6" class="data row1 col6" >774971.12</td>
#     </tr>
#     <tr>
#       <th id="T_90bdc_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_90bdc_row2_col0" class="data row2 col0" >3.01</td>
#       <td id="T_90bdc_row2_col1" class="data row2 col1" >51618.55</td>
#       <td id="T_90bdc_row2_col2" class="data row2 col2" >4.17</td>
#       <td id="T_90bdc_row2_col3" class="data row2 col3" >521.11</td>
#       <td id="T_90bdc_row2_col4" class="data row2 col4" >42.97</td>
#       <td id="T_90bdc_row2_col5" class="data row2 col5" >0.81</td>
#       <td id="T_90bdc_row2_col6" class="data row2 col6" >894128.36</td>
#     </tr>
#     <tr>
#       <th id="T_90bdc_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_90bdc_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_90bdc_row3_col1" class="data row3 col1" >100.00</td>
#       <td id="T_90bdc_row3_col2" class="data row3 col2" >4.00</td>
#       <td id="T_90bdc_row3_col3" class="data row3 col3" >793.00</td>
#       <td id="T_90bdc_row3_col4" class="data row3 col4" >38.40</td>
#       <td id="T_90bdc_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_90bdc_row3_col6" class="data row3 col6" >40000.00</td>
#     </tr>
#     <tr>
#       <th id="T_90bdc_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_90bdc_row4_col0" class="data row4 col0" >4.00</td>
#       <td id="T_90bdc_row4_col1" class="data row4 col1" >30000.00</td>
#       <td id="T_90bdc_row4_col2" class="data row4 col2" >17.00</td>
#       <td id="T_90bdc_row4_col3" class="data row4 col3" >1197.00</td>
#       <td id="T_90bdc_row4_col4" class="data row4 col4" >74.00</td>
#       <td id="T_90bdc_row4_col5" class="data row4 col5" >5.00</td>
#       <td id="T_90bdc_row4_col6" class="data row4 col6" >385000.00</td>
#     </tr>
#     <tr>
#       <th id="T_90bdc_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_90bdc_row5_col0" class="data row5 col0" >6.00</td>
#       <td id="T_90bdc_row5_col1" class="data row5 col1" >50000.00</td>
#       <td id="T_90bdc_row5_col2" class="data row5 col2" >19.67</td>
#       <td id="T_90bdc_row5_col3" class="data row5 col3" >1248.00</td>
#       <td id="T_90bdc_row5_col4" class="data row5 col4" >88.50</td>
#       <td id="T_90bdc_row5_col5" class="data row5 col5" >5.00</td>
#       <td id="T_90bdc_row5_col6" class="data row5 col6" >556000.00</td>
#     </tr>
#     <tr>
#       <th id="T_90bdc_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_90bdc_row6_col0" class="data row6 col0" >8.00</td>
#       <td id="T_90bdc_row6_col1" class="data row6 col1" >70000.00</td>
#       <td id="T_90bdc_row6_col2" class="data row6 col2" >22.70</td>
#       <td id="T_90bdc_row6_col3" class="data row6 col3" >1582.00</td>
#       <td id="T_90bdc_row6_col4" class="data row6 col4" >117.30</td>
#       <td id="T_90bdc_row6_col5" class="data row6 col5" >5.00</td>
#       <td id="T_90bdc_row6_col6" class="data row6 col6" >825000.00</td>
#     </tr>
#     <tr>
#       <th id="T_90bdc_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_90bdc_row7_col0" class="data row7 col0" >29.00</td>
#       <td id="T_90bdc_row7_col1" class="data row7 col1" >3800000.00</td>
#       <td id="T_90bdc_row7_col2" class="data row7 col2" >33.54</td>
#       <td id="T_90bdc_row7_col3" class="data row7 col3" >6592.00</td>
#       <td id="T_90bdc_row7_col4" class="data row7 col4" >626.00</td>
#       <td id="T_90bdc_row7_col5" class="data row7 col5" >9.00</td>
#       <td id="T_90bdc_row7_col6" class="data row7 col6" >39500000.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Most cars in the dataset are around 6 years old, have been driven about 55,000 km, and give an average mileage of 19.7 km/l.
# - Engine sizes and power vary a lot, but most cars have 5 seats.
# - Typical selling prices range widely, with a median around ₹5.5 lakh.

# %%
data.head(5)
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %% [markdown]
# 3. Checking for <code>nulls</code> and <code>duplicates</code>

# %%
data.isna().sum()
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(167)

# %% [markdown]
# Data is devoid of null values, but contains 167 duplicates. Removing them is necessary for model accuracy.

# %%
print(f"Shape of data before removing duplicates: {data.shape}")
data.drop_duplicates(inplace = True)
print(f"Shape of data after removing duplicates: {data.shape}")
# Out:
# Shape of data before removing duplicates: (15411, 13)
# Shape of data after removing duplicates: (15244, 13)

# %% [markdown]
# 4. <code>Data Preprocessing</code>

# %%
model_data = data.copy()

# %%
model_data.head(5)
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %% [markdown]
# - Preprocessing <code>text</code> columns

# %% [markdown]
# Dropping <code>car_name</code> column

# %%
model_data.drop("car_name", axis = 1, inplace = True)

# %%
model_data.head(5)
# Out:
#      brand     model  vehicle_age  km_driven seller_type fuel_type  \
# 0   Maruti      Alto            9     120000  Individual    Petrol
# 1  Hyundai     Grand            5      20000  Individual    Petrol
# 2  Hyundai       i20           11      60000  Individual    Petrol
# 3   Maruti      Alto            9      37000  Individual    Petrol
# 4     Ford  Ecosport            6      30000      Dealer    Diesel
#
#   transmission_type  mileage  engine  max_power  seats  selling_price
# 0            Manual    19.70     796      46.30      5         120000
# 1            Manual    18.90    1197      82.00      5         550000
# 2            Manual    17.00    1197      80.00      5         215000
# 3            Manual    20.92     998      67.10      5         226000
# 4            Manual    22.77    1498      98.59      5         570000

# %% [markdown]
# Removing <code>Outliers</code>

# %%
for col in ["km_driven", "mileage", "engine", "max_power"]:
    Q1 = model_data[col].quantile(0.25)
    Q3 = model_data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    model_data = model_data[(model_data[col] >= lower_bound) & (model_data[col] <= upper_bound)]

# %%
model_data.shape
# Out:
# (11960, 12)

# %% [markdown]
# Creating <code>Pipelines</code> for other <code>Preprocessing</code> activities

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
cat_cols = ["brand", "model", "seller_type", "fuel_type", "transmission_type"]
num_cols = ["vehicle_age", "km_driven", "mileage", "engine", "max_power", "seats"]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("onehot", OneHotEncoder(handle_unknown="ignore"), cat_cols),
        ("scale", StandardScaler(), num_cols)
    ]   
)

# %% [markdown]
# 5. Model Building

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(random_state = 10)

# %%
pipeline = Pipeline([
    ("preprocessing", preprocessor),
    ("model", model)
])

# %%
parameters = {
    'model__n_estimators': np.arange(100, 500, 50),
    'model__max_depth': np.arange(10, 100, 10),
    'model__min_samples_split': np.arange(2, 8, 1),
    'model__min_samples_leaf': np.arange(1, 5, 1)
}

# %% [markdown]
# <code>Hypertuning</code> Parameters

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_search = RandomizedSearchCV(
    estimator = pipeline,
    param_distributions = parameters,
    n_iter = 20,
    cv = 5,
    scoring = "neg_mean_squared_error",
    random_state = 10
)

# %% [markdown]
# Train-Validation split

# %%
from sklearn.model_selection import train_test_split

# %%
X = model_data.drop("selling_price", axis = 1)
y = model_data["selling_price"]

# %%
trainX, valX, trainY, valY = train_test_split(X, y, test_size = 0.2, random_state = 10)

# %%
pipeline.fit(trainX, trainY)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['brand', 'model',
#                                                    'seller_type', 'fuel_type',
#                                                    'transmission_type']),
#                                                  ('scale', StandardScaler(),
#                                                   ['vehicle_age', 'km_driven',
#                                                    'mileage', 'engine',
#                                                    'max_power', 'seats'])])),
#                 ('model', RandomForestRegressor(random_state=10))])

# %% [markdown]
# Evaluating Performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
yhat = pipeline.predict(valX)
mse = mean_squared_error(valY, yhat)
r2 = r2_score(valY, yhat)
print(f"Mean Squared Error : {mse:.2f}")
print(f"R2 Score : {r2:.2f}")
# Out:
# Mean Squared Error : 8427553670.14
# R2 Score : 0.88

# %% [markdown]
# <code>MSE</code> is 8427553670.14. So our model has <code>+-90K error range</code>.

# %% [markdown]
# Saving the model pipeline

# %%
import joblib

# %%
joblib.dump(pipeline, "./models/used_car_price_model.pkl")
# Out:
# ['./models/used_car_price_model.pkl']
